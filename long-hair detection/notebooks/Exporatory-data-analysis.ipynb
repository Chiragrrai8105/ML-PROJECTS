# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in C:\Users\chira\AppData\Roaming\Python\Python314\site-packages (3.0.2)
# Requirement already satisfied: numpy>=2.3.3 in C:\Users\chira\AppData\Roaming\Python\Python314\site-packages (from pandas) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\chira\AppData\Roaming\Python\Python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\chira\AppData\Roaming\Python\Python314\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\chira\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in C:\Users\chira\AppData\Roaming\Python\Python314\site-packages (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\chira\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\chira\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\chira\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\chira\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in C:\Users\chira\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in C:\Users\chira\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in C:\Users\chira\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\chira\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\chira\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\chira\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in C:\Users\chira\AppData\Roaming\Python\Python314\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in C:\Users\chira\AppData\Roaming\Python\Python314\site-packages (from seaborn) (2.4.4)
# Requirement already satisfied: pandas>=1.2 in C:\Users\chira\AppData\Roaming\Python\Python314\site-packages (from seaborn) (3.0.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in C:\Users\chira\AppData\Roaming\Python\Python314\site-packages (from seaborn) (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\chira\AppData\Roaming\Python\Python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\chira\AppData\Roaming\Python\Python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\chira\AppData\Roaming\Python\Python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\chira\AppData\Roaming\Python\Python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\chira\AppData\Roaming\Python\Python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=8 in C:\Users\chira\AppData\Roaming\Python\Python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\chira\AppData\Roaming\Python\Python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\chira\AppData\Roaming\Python\Python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\chira\AppData\Roaming\Python\Python314\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\chira\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting opencv-python
#   Downloading opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=2 in C:\Users\chira\AppData\Roaming\Python\Python314\site-packages (from opencv-python) (2.4.4)
# Downloading opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl (40.2 MB)
#    ---------------------------------------- 0.0/40.2 MB ? eta -:--:--
#    ---------------------------------------- 0.3/40.2 MB ? eta -:--:--
#     --------------------------------------- 0.5/40.2 MB 2.2 MB/s eta 0:00:19
#    - -------------------------------------- 1.0/40.2 MB 2.2 MB/s eta 0:00:18
#    - -------------------------------------- 1.6/40.2 MB 2.4 MB/s eta 0:00:17
#    -- ------------------------------------- 2.4/40.2 MB 2.5 MB/s eta 0:00:15
#    --- ------------------------------------ 3.1/40.2 MB 2.8 MB/s eta 0:00:14
#    --- ------------------------------------ 3.9/40.2 MB 3.1 MB/s eta 0:00:12
#    ---- ----------------------------------- 5.0/40.2 MB 3.3 MB/s eta 0:00:11
#    ----- ---------------------------------- 6.0/40.2 MB 3.6 MB/s eta 0:00:10
#    ------ --------------------------------- 6.8/40.2 MB 3.7 MB/s eta 0:00:09
#    -------- ------------------------------- 8.1/40.2 MB 3.9 MB/s eta 0:00:09
#    --------- ------------------------------ 10.0/40.2 MB 4.2 MB/s eta 0:00:08
#    ----------- ---------------------------- 11.8/40.2 MB 4.7 MB/s eta 0:00:07
#    ------------- -------------------------- 13.6/40.2 MB 5.0 MB/s eta 0:00:06
#    -------------- ------------------------- 14.7/40.2 MB 5.0 MB/s eta 0:00:06
#    --------------- ------------------------ 15.2/40.2 MB 4.9 MB/s eta 0:00:06
#    --------------- ------------------------ 15.5/40.2 MB 4.7 MB/s eta 0:00:06
#    --------------- ------------------------ 15.7/40.2 MB 4.5 MB/s eta 0:00:06
#    --------------- ------------------------ 15.7/40.2 MB 4.5 MB/s eta 0:00:06
#    --------------- ------------------------ 16.0/40.2 MB 4.2 MB/s eta 0:00:06
#    ---------------- ----------------------- 16.3/40.2 MB 4.0 MB/s eta 0:00:07
#    ---------------- ----------------------- 16.5/40.2 MB 3.8 MB/s eta 0:00:07
#    ---------------- ----------------------- 16.8/40.2 MB 3.6 MB/s eta 0:00:07
#    ---------------- ----------------------- 16.8/40.2 MB 3.6 MB/s eta 0:00:07
#    ---------------- ----------------------- 17.0/40.2 MB 3.5 MB/s eta 0:00:07
#    ----------------- ---------------------- 17.3/40.2 MB 3.3 MB/s eta 0:00:07
#    ----------------- ---------------------- 17.6/40.2 MB 3.2 MB/s eta 0:00:08
#    ----------------- ---------------------- 17.8/40.2 MB 3.1 MB/s eta 0:00:08
#    ----------------- ---------------------- 17.8/40.2 MB 3.1 MB/s eta 0:00:08
#    ----------------- ---------------------- 18.1/40.2 MB 3.0 MB/s eta 0:00:08
#    ------------------ --------------------- 18.4/40.2 MB 2.9 MB/s eta 0:00:08
#    ------------------ --------------------- 18.6/40.2 MB 2.9 MB/s eta 0:00:08
#    ------------------ --------------------- 18.9/40.2 MB 2.8 MB/s eta 0:00:08
#    ------------------- -------------------- 19.1/40.2 MB 2.8 MB/s eta 0:00:08
#    ------------------- -------------------- 19.4/40.2 MB 2.7 MB/s eta 0:00:08
#    ------------------- -------------------- 19.4/40.2 MB 2.7 MB/s eta 0:00:08
#    ------------------- -------------------- 19.7/40.2 MB 2.7 MB/s eta 0:00:08
#    ------------------- -------------------- 19.9/40.2 MB 2.6 MB/s eta 0:00:08
#    -------------------- ------------------- 20.2/40.2 MB 2.6 MB/s eta 0:00:08
#    -------------------- ------------------- 20.4/40.2 MB 2.6 MB/s eta 0:00:08
#    -------------------- ------------------- 21.0/40.2 MB 2.5 MB/s eta 0:00:08
#    --------------------- ------------------ 21.2/40.2 MB 2.5 MB/s eta 0:00:08
#    --------------------- ------------------ 21.5/40.2 MB 2.4 MB/s eta 0:00:08
#    --------------------- ------------------ 21.8/40.2 MB 2.4 MB/s eta 0:00:08
#    --------------------- ------------------ 22.0/40.2 MB 2.4 MB/s eta 0:00:08
#    ---------------------- ----------------- 22.3/40.2 MB 2.4 MB/s eta 0:00:08
#    ---------------------- ----------------- 22.8/40.2 MB 2.4 MB/s eta 0:00:08
#    ---------------------- ----------------- 23.1/40.2 MB 2.3 MB/s eta 0:00:08
#    ----------------------- ---------------- 23.3/40.2 MB 2.3 MB/s eta 0:00:08
#    ----------------------- ---------------- 23.6/40.2 MB 2.3 MB/s eta 0:00:08
#    ----------------------- ---------------- 23.9/40.2 MB 2.3 MB/s eta 0:00:08
#    ------------------------ --------------- 24.4/40.2 MB 2.3 MB/s eta 0:00:07
#    ------------------------ --------------- 24.6/40.2 MB 2.3 MB/s eta 0:00:07
#    ------------------------ --------------- 24.9/40.2 MB 2.3 MB/s eta 0:00:07
#    ------------------------- -------------- 25.2/40.2 MB 2.2 MB/s eta 0:00:07
#    ------------------------- -------------- 25.7/40.2 MB 2.2 MB/s eta 0:00:07
#    ------------------------- -------------- 26.0/40.2 MB 2.2 MB/s eta 0:00:07
#    -------------------------- ------------- 26.5/40.2 MB 2.2 MB/s eta 0:00:07
#    -------------------------- ------------- 27.0/40.2 MB 2.2 MB/s eta 0:00:06
#    --------------------------- ------------ 27.5/40.2 MB 2.2 MB/s eta 0:00:06
#    --------------------------- ------------ 27.8/40.2 MB 2.2 MB/s eta 0:00:06
#    ---------------------------- ----------- 28.3/40.2 MB 2.2 MB/s eta 0:00:06
#    ---------------------------- ----------- 28.8/40.2 MB 2.2 MB/s eta 0:00:06
#    ----------------------------- ---------- 29.6/40.2 MB 2.2 MB/s eta 0:00:05
#    ----------------------------- ---------- 30.1/40.2 MB 2.2 MB/s eta 0:00:05
#    ------------------------------ --------- 30.9/40.2 MB 2.3 MB/s eta 0:00:05
#    ------------------------------- -------- 31.5/40.2 MB 2.3 MB/s eta 0:00:04
#    -------------------------------- ------- 32.2/40.2 MB 2.3 MB/s eta 0:00:04
#    -------------------------------- ------- 33.0/40.2 MB 2.3 MB/s eta 0:00:04
#    --------------------------------- ------ 33.8/40.2 MB 2.3 MB/s eta 0:00:03
#    ---------------------------------- ----- 34.6/40.2 MB 2.4 MB/s eta 0:00:03
#    ----------------------------------- ---- 35.9/40.2 MB 2.4 MB/s eta 0:00:02
#    ------------------------------------ --- 36.7/40.2 MB 2.4 MB/s eta 0:00:02
#    ------------------------------------- -- 38.0/40.2 MB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 38.5/40.2 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  39.3/40.2 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  40.1/40.2 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 40.2/40.2 MB 2.5 MB/s  0:00:16
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.13.0.92
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os

dataset_path = r"D:\dataset\p1"

images = []

for root, dirs, files in os.walk(dataset_path):
    for file in files:
        if file.lower().endswith(('.jpg', '.jpeg', '.png')):
            images.append(os.path.join(root, file))

print("Total images:", len(images))
print(images[:5])
# Out:
# Total images: 67776
# ['D:\\dataset\\p1\\age\\crop_part1\\100_1_0_20170110183726390.jpg.chip.jpg', 'D:\\dataset\\p1\\age\\crop_part1\\100_1_2_20170105174847679.jpg.chip.jpg', 'D:\\dataset\\p1\\age\\crop_part1\\101_1_2_20170105174739309.jpg.chip.jpg', 'D:\\dataset\\p1\\age\\crop_part1\\10_0_0_20161220222308131.jpg.chip.jpg', 'D:\\dataset\\p1\\age\\crop_part1\\10_0_0_20170103200329407.jpg.chip.jpg']

# %%
import cv2
import os
import matplotlib.pyplot as plt

widths=[]
heights=[]

for img in images:

    image=cv2.imread(img)

    h,w,_=image.shape

    heights.append(h)
    widths.append(w)

plt.hist(widths)
plt.title("Width Distribution")
plt.show()

# %%
import os
from collections import Counter

label_path = r"D:\dataset\p1\Hair\train\labels"

labels = []

for file in os.listdir(label_path):
    if file.endswith(".txt"):
        with open(os.path.join(label_path, file), "r") as f:
            line = f.readline().strip()

            if line:
                class_id = int(line.split()[0])
                labels.append(class_id)

print("Total labels:", len(labels))
print(Counter(labels))
# Out:
# Total labels: 768
# Counter({0: 386, 1: 382})

# %%
import seaborn as sns
sns.countplot(x=labels)
# Out:
# <Axes: ylabel='count'>
